# %% [markdown]
# ### Prep

# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tm = datetime.time(20, 10, 33)
print(tm)
print(tm.hour, tm.minute, tm.second)
type(tm)

# %%
dt = datetime.date(2020, 5, 23)
print(dt)
print(dt.year, dt.month, dt.day)
type(dt)

# %%
dtm = datetime.datetime(2020, 5, 23, 20, 10, 33)
print(dtm)
print(dtm.year, dtm.month, dtm.day, dtm.hour, dtm.minute, dtm.second)
print(dtm.weekday(), dtm.isoweekday())
type(dtm)

# %%
print(datetime.datetime.today())
print(datetime.date.today())

# %%
dt.replace(year = 2000)

# %%
dtm.replace(year = 2000)

# %%
datetime.datetime.today().timetuple()

# %%
x = np.arange(0, 10, 1)
print(x)
type(x)

# %%
np.random.seed(42)
np.random.rand(4)

# %%
pd.date_range('2020-05-22', periods = 2, freq = 'D')

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns = 'A B'.split())

# %%
df['A'].plot.hist(edgecolor = 'k').autoscale(enable = True, axis = 'both', tight = True)

# %%
df.plot.bar()

# %%
df.plot.bar(stacked = True)

# %%
df.plot.barh()

# %%
df.plot.line(y = 'A')

# %%
df.plot.line(lw = 5)

# %%
df.plot.line(y = 'A', ls = '--')
df.plot.line(y = 'B', ls = '-.')

# %%
df.plot.area()

# %%
df.plot.area(alpha = 0.5)

# %%
df.plot.area(stacked = False, alpha = 0.5)

# %%
df.plot.scatter('A', 'B')

# %%
df.plot.scatter('A', 'B', c = 'A', cmap = 'coolwarm')

# %%
df.plot.scatter('A', 'B', s = df['A']*50, alpha = 0.5)

# %%
df.boxplot()

# %%
df.plot.box()

# %%
df.plot.kde()

# %%
df.plot.density()

# %%
pd.DataFrame(np.random.randn(1000, 2), columns = 'A B'.split()).plot.hexbin(x = 'A', y = 'B', gridsize = 25, cmap = 'Oranges')

# %% [markdown]
# ### TSA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/tsa.csv', parse_dates = True)

# %%
df['Month'] = pd.to_datetime(df['Month'])
df = df.set_index('Month')
df.index
df.index.freq = 'MS'
df.columns = ['Passengers']

# %%
df['Average'] = df['Passengers'].mean()

# %%
df[['Passengers', 'Average']].plot(figsize = (10, 5));

# %%
df['6-month-SMA'] = df['Passengers'].rolling(window = 6).mean()
df['12-month-SMA'] = df['Passengers'].rolling(window = 12).mean()

# %%
df.head(15)

# %%
df.plot(figsize = (10, 5));

# %%
from sklearn.model_selection import cross_val_score

# %%
acc = cross_val_score(regressor, X_train, y_train, cv = 5)

# %%
acc.mean()

# %%
acc.std()

# %%
x = np.linspace(0, 50, 100)
noise = np.random.normal(0.0, 3.0, len(x))
m = 2
b = 1
y = (m * x) + b + noise

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(x, y)

from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression

regressor1 = XGBRegressor()
regressor1.fit(x, y)

regressor2 = LinearRegression()
regressor2.fit(x, y)

from sklearn.metrics import mean_squared_error
mean_squared_error(y, y_pred)


x_test = np.linspace(0, 50, 100).reshape(-1, 1)
y_pred1 = regressor1.predict(x_test)
y_pred2 = regressor2.predict(x_test)

plt.figure(figsize = (10, 5))
plt.plot(x, y, '*')
plt.plot(x, y_pred1, label = 'XGB')
plt.plot(x_test, y_pred2, label = 'LR')
plt.legend()

# %% [markdown]
# ### DNN

# %%
import numpy as np
import pandas as pd
import keras

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
m = 2
b = 3
x = np.linspace(0, 50, 100)

# %%
noise = np.random.normal(loc = 0.0, scale = 4.0, size = len(x))

# %%
y = (m * x) + b + noise

# %%
plt.plot(x, y, '*')

# %%
from keras.models import Sequential

# %%
from keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(units = 4, input_dim = 1, activation = 'relu'))
model.add(Dense(units = 4, activation = 'relu'))
model.add(Dense(units = 1, activation = 'linear'))

# %%
model.summary()

# %%
model.compile(optimizer = 'adam', loss = 'mse')

# %%
model.fit(x, y, epochs = 300)

# %%
y_pred = model.predict(x)

# %%
plt.figure(figsize=(12, 6))
plt.plot(x, y, '*')
plt.plot(x, y_pred)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y, y_pred)

# %%
plt.plot(range(0, 300), model.history.history['loss'])
